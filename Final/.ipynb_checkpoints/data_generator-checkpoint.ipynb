# %%
import numpy
import matplotlib.pyplot as plt
import csv

# %%
def noise():
    return numpy.random.normal()

# %%
def resp_time(m, x, c):
    y = m*x + c
    return -y + noise()

# %%
trials = 104
m = -1
c = 4
rt = list()

# %%
for i in range(trials, c, -1):
    rt.append(resp_time(m, i, c))

# %%
def dist_covered(x):
    return numpy.log(x) + noise()

# %%
dist = list()

# %%
for i in range(c, trials):
    dist.append(dist_covered(i))

# %%
plt.plot(dist)

# %%
plt.plot(rt)

# %%
with open('data.csv', mode = 'w') as data:
    data_writer = csv.writer(data)
    data_writer.writecol(rt)
    data_writer.writecol(dist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-20d290235940> in <module>()
#       1 with open('data.csv', mode = 'w') as data:
#       2     data_writer = csv.writer(data)
# ----> 3     data_writer.writecol(rt)
#       4     data_writer.writecol(dist)
#
# AttributeError: '_csv.writer' object has no attribute 'writecol'
